# %% [markdown]
# <a href="https://colab.research.google.com/github/brodyandre/lendo_uma_pagina_html_wikipedia/blob/main/lendo_uma_pagina_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de População de Países
# Esta análise tem como objetivo explorar os dados de população dos países, extraídos da Wikipédia. Através de um DataFrame do Pandas, organizaremos e limparemos as informações para facilitar futuras análises.

# %% [markdown]
# # 📌 Bibliotecas Utilizadas
#
# pandas: Para manipulação e análise de dados.

# %% [markdown]
# #📌 Coleta de Dados
#
# Os dados foram obtidos diretamente de uma página da Wikipédia, que contém uma lista de países por população. Para isso, utilizamos o método pd.read_html() da biblioteca Pandas, que permite extrair tabelas HTML e convertê-las em DataFrames.

# %%
import pandas as pd

# Coleta dos dados a partir de um arquivo HTML salvo localmente
dados_html = pd.read_html('/content/Lista de países por população – Wikipédia, a enciclopédia livre.html')

# %% [markdown]
# * O método pd.read_html() retorna uma lista de DataFrames, onde cada um corresponde a uma tabela identificada na página HTML.
#
# * Verificamos o tipo e o tamanho da lista para entender quantas tabelas foram identificadas.

# %%
type(dados_html)
len(dados_html)
# Out:
# 3

# %% [markdown]
# #📌 Selecionando a Tabela Correta
#
# Após inspecionar o conteúdo da lista, selecionamos o primeiro DataFrame, que contém os dados de população dos países.

# %%
populacao_paises = dados_html[0]
populacao_paises
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       346 353 341
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)             1 100
# 246         NaN     195                           Vaticano               879
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248         NaN       –     Tristão da Cunha (Reino Unido)               264
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                67
#
# ...

# %% [markdown]
# #📌 Limpeza dos Dados
#
# Identificamos a presença de uma coluna desnecessária, nomeada como Unnamed: 0. Essa coluna foi removida para melhorar a visualização e organização dos dados.

# %%
# Removendo a coluna 'Unnamed: 0'
populacao_paises = populacao_paises.drop(columns=['Unnamed: 0'])

# %%
populacao_paises
# Out:
#     Posição    País (ou território dependente) Estimativa da ONU  \
# 0         1                              Índia     1 429 921 746
# 1         2                              China     1 426 391 281
# 2         3                     Estados Unidos       346 353 341
# 3         4                          Indonésia       277 184 719
# 4         5                          Paquistão       240 215 932
# ..      ...                                ...               ...
# 245       –     Ilha de Ascensão (Reino Unido)             1 100
# 246     195                           Vaticano               879
# 247       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248       –     Tristão da Cunha (Reino Unido)               264
# 249       –       Ilhas Pitcairn (Reino Unido)                67
#
#     Crescimento desde a última estimativa      Estimativa Oficial
# 0                            +269.108.746      Estimativa oficial
# ...

# %% [markdown]
# # 📌 Próximos Passos
#
# 1. Realizar uma análise exploratória (EDA) dos dados:
#
#  *   Estatísticas descritivas
#
#  *   Visualização de distribuição populacional
#
#  *   Ranking de países mais populosos
#
# 2. Tratamento de dados faltantes (caso existam) e padronização dos formatos.
#
# 3. Geração de gráficos e dashboards para melhor interpretação dos resultados.

# %% [markdown]
# # 📌 Conclusão
#
# Os dados foram coletados e organizados com sucesso, prontos para serem explorados em etapas futuras. A próxima fase será focada em EDA e visualizações para obter insights valiosos sobre a distribuição populacional global.

# %% [markdown]
# Autor: Luiz AndréÚltima atualização: 08 de Maio de 2025
# ""
